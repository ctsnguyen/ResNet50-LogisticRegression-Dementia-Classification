# %% [markdown]
# #Importing OASIS-1 and OASIS-2 Datasets
#
# - Be careful running this: it will download the entire dataset into our shared Google Drive
# - Also take care not to open any of the download links in your browser, it might download 8-10GB of data
# - The "OASIS-1: Demographic and Clinical Data" and "OASIS-2 Longitudinal Subject Data" are small files so they don't need to be imported
# - I accidentally forgot to put the Data folder in the filepath so it downloads to the root of the drive, my bad -Corey

# %%
from google.colab import drive
drive.mount('/content/drive')

urls = [
    # OASIS-1 Raw Data Download
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc1.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc2.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc3.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc4.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc5.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc6.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc7.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc8.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc9.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc10.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc11.tar.gz",
    "https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc12.tar.gz",

    # OASIS-2 Longitudinal Scan Data
    "https://download.nrg.wustl.edu/data/OAS2_RAW_PART1.tar.gz",
    "https://download.nrg.wustl.edu/data/OAS2_RAW_PART2.tar.gz"
]

dest = "/content/drive/Shareddrives/[YOUR-SHARED-DRIVE-NAME]/"

for url in urls:
    # !wget -P "{dest}" "{url}"
# Out:
# Mounted at /content/drive
# --2025-11-01 17:44:29--  https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc1.tar.gz
# Resolving download.nrg.wustl.edu (download.nrg.wustl.edu)... 128.252.217.126
# Connecting to download.nrg.wustl.edu (download.nrg.wustl.edu)|128.252.217.126|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1380527970 (1.3G) [application/x-gzip]
# Saving to: ‘/content/drive/Shareddrives/[YOUR-SHARED-DRIVE-NAME]/oasis_cross-sectional_disc1.tar.gz’
#
# oasis_cross-section 100%[===================>]   1.29G  34.1MB/s    in 39s
#
# 2025-11-01 17:45:08 (34.0 MB/s) - ‘/content/drive/Shareddrives/[YOUR-SHARED-DRIVE-NAME]/oasis_cross-sectional_disc1.tar.gz’ saved [1380527970/1380527970]
#
# --2025-11-01 17:45:08--  https://download.nrg.wustl.edu/data/oasis_cross-sectional_disc2.tar.gz
# Resolving download.nrg.wustl.edu (download.nrg.wustl.edu)... 128.252.217.126
# ...
